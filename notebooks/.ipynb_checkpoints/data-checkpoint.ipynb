# %%
# %config Completer.use_jedi = False

import json
import os
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('../data/openstack_links.csv')
# df = df[['commit_id', 'buggy', 'fix']]
# df.set_index('HashId', inplace=True)
df
# Out:
#      Project                                    HashId    BugId BugType  \
# 0     cinder  015555acb75ee4d9298915951d2bfaf0d19d2b02  1301854     Bug
# 1     cinder  015555acb75ee4d9298915951d2bfaf0d19d2b02  1332482     Bug
# 2     cinder  0278a38153f9649aab1cc641bfabd8d5738d2d8c  1246228     Bug
# 3     cinder  027b78a214e1f7ab7bbda342a024cb13dae8944d  1250249     Bug
# 4     cinder  027b78a214e1f7ab7bbda342a024cb13dae8944d  1250249     Bug
# ...      ...                                       ...      ...     ...
# 8245   swift  ed5101b2002b877518466ae5f9a6d652581238f2  1317257     Bug
# 8246   swift  f5caac43ac40e103f3f2156eedb313385dbb6ba8  1348869     Bug
# 8247   swift  f5caac43ac40e103f3f2156eedb313385dbb6ba8  1348869     Bug
# 8248   swift  f68b6354e28f840d4a07f633888751c782267662  1179007     Bug
# 8249   swift  fa3c871f0b1544f859bacf38497580afd69ced0b  1285040     Bug
#
#       BugReportDate     FixDate                                 FixHashId  \
# 0        1394502624  1396535798  1fdb38fd4b43c2685658c1a7aa6a56c92ac31585
# 1        1394502624  1403273920  b07c1a759c8a0cdaaaaaf3e6f1ad7402bf631a44
# 2        1378717264  1383138656  a29a1d8802d2fde8d09bed08e0595b4c0f85cf7b
# 3        1357682995  1384230241  9834639454103ee2ba980628f0bc67ad0baa94ff
# 4        1357682995  1384230241  9834639454103ee2ba980628f0bc67ad0baa94ff
# ...             ...         ...                                       ...
# 8245     1382154035  1399509173  b61fce6cbabf2181fed3f0c4bb83a2d3c40db100
# 8246     1399545067  1406360766  6978275cdb04bb08aaf142d401b52a46527dac4c
# 8247     1399545067  1406360766  6978275cdb04bb08aaf142d401b52a46527dac4c
# 8248     1306376652  1368303138  4332bff3f500f062e7e06edccf0da5a9d9379d79
# 8249     1289950539  1393423059  87710cc8a2654d872adb74d4fa4856c9beb41fbd
#
#                                                    File
# 0                      cinder/tests/test_vmware_vmdk.py
# 1                      cinder/tests/test_vmware_vmdk.py
# 2                    cinder/api/contrib/types_manage.py
# 3                           cinder/tests/test_hp3par.py
# 4        cinder/volume/drivers/san/hp/hp_3par_common.py
# ...                                                 ...
# 8245                     test/unit/common/test_utils.py
# 8246   swift/common/middleware/x_profile/html_viewer.py
# 8247  swift/common/middleware/x_profile/profile_mode...
# 8248                                           setup.py
# 8249                     test/functional/test_object.py
#
# [8250 rows x 8 columns]

# %%
nova = df[df['Project'] == 'nova']

# %%
len(nova['FixHashId'].unique())
# Out:
# 773

# %%
pd.concat([train_df['HashId'], train_df['FixHashId']]).unique()
# Out:
# array(['001d36c97eac77410f7dd32290d2142abfb19fa0',
#        '002ce47d757461546c24a4e8ba909fca42c38997',
#        '0165ff51f9b9a45dcab0418be24d3c8cab31ab5f', ...,
#        'a3aeace9afd5c533f040452f33482fdb55d93927',
#        'd19c75c19d2de8b20e82e6de9413ba53671ad7fb',
#        'eef97cdf4bb7f426d7feb394ef54510db8b1656b'], dtype=object)

# %%
nova = df[df['Project'] == 'nova']

# %%
df[df['FixHashId'] == 'd0225509bdb7882324726312f4a4a9f63375203e']
# Out:
#      Project                                    HashId    BugId BugType  \
# 5002    nova  0df60e98790c722aef59d0015c209ea0944e62c0  1333219     Bug
# 5146    nova  1a5c23a2810d4c887d1239eeab09dd9904892c8e  1333219     Bug
# 5490    nova  32632c488388a2f60d14bcd63b4bbdee6f4995c3  1333219     Bug
# 6808    nova  9408d79e7413aadcba52a61b7a33164090785e4f  1333219     Bug
# 7763    nova  e1f04d8ef1d7dec03d71fb6e9ad13f759e1082a0  1333219     Bug
# 7867    nova  eaef552a1f0c4161d8b303aa4a0090ece9ab9a4e  1333219     Bug
# 8101    nova  fff46247c058e69fcdf25e6845c34509f4688c30  1333219     Bug
#
#       BugReportDate     FixDate                                 FixHashId  \
# 5002     1357327032  1403537871  d0225509bdb7882324726312f4a4a9f63375203e
# 5146     1380080322  1403537871  d0225509bdb7882324726312f4a4a9f63375203e
# 5490     1371620910  1403537871  d0225509bdb7882324726312f4a4a9f63375203e
# 6808     1378311552  1403537871  d0225509bdb7882324726312f4a4a9f63375203e
# 7763     1379584384  1403537871  d0225509bdb7882324726312f4a4a9f63375203e
# 7867     1360001398  1403537871  d0225509bdb7882324726312f4a4a9f63375203e
# 8101     1359157126  1403537871  d0225509bdb7882324726312f4a4a9f63375203e
#
#                                               File
# 5002                 nova/virt/vmwareapi/driver.py
# 5146                 nova/virt/vmwareapi/driver.py
# 5490  nova/tests/virt/vmwareapi/test_driver_api.py
# 6808                 nova/virt/vmwareapi/driver.py
# 7763  nova/tests/virt/vmwareapi/test_driver_api.py
# 7867                 nova/virt/vmwareapi/driver.py
# 8101                 nova/virt/vmwareapi/driver.py

# %%
len(nova)
# Out:
# 3236

# %%
nova[['HashId','FixHashId']]
# Out:
#                                         HashId  \
# 4867  001d36c97eac77410f7dd32290d2142abfb19fa0
# 4868  002ce47d757461546c24a4e8ba909fca42c38997
# 4869  002ce47d757461546c24a4e8ba909fca42c38997
# 4870  002ce47d757461546c24a4e8ba909fca42c38997
# 4871  002ce47d757461546c24a4e8ba909fca42c38997
# ...                                        ...
# 8098  ff693722639387a7a3ea62e291a8306569392ab9
# 8099  ff6a3dc031d782d01607e28c8bd3fb5aa396bb16
# 8100  ff6e64992bf40fd2ac6618cbe50b8844e35b6538
# 8101  fff46247c058e69fcdf25e6845c34509f4688c30
# 8102  fff46247c058e69fcdf25e6845c34509f4688c30
#
#                                      FixHashId
# 4867  2fc92d9bd7b4e212a3f28e57565a4cf260982f30
# 4868  1e54cae3d3f562046a50ab20ff60e2879ce80438
# 4869  1e54cae3d3f562046a50ab20ff60e2879ce80438
# 4870  1e54cae3d3f562046a50ab20ff60e2879ce80438
# 4871  45553a6dda84ef6be38150071f8bb6fa9850a53e
# ...                                        ...
# 8098  721709a9d14a51170a96f8983d413d5aa3f6aafc
# 8099  4afece5aba8882ef1f53ea1a171b2afa69bdadb1
# 8100  8f299f5545e19b36533742458de43649d41080ed
# 8101  d0225509bdb7882324726312f4a4a9f63375203e
# 8102  1deb31f85a8f5d1e261b2cf1eddc537a5da7f60b
#
# [3236 rows x 2 columns]

# %%
len(nova['FixHashId'].unique())
# Out:
# 773

# %%
pd.DataFrame(pd.concat([nova['HashId'], nova['FixHashId']]).unique())
# Out:
#                                              0
# 0     001d36c97eac77410f7dd32290d2142abfb19fa0
# 1     002ce47d757461546c24a4e8ba909fca42c38997
# 2     0165ff51f9b9a45dcab0418be24d3c8cab31ab5f
# 3     01985dd44d1b29c7ad7cb0932a1d30f7b6fe1911
# 4     01a44568cc60bb5a6dd7b55d69b20bba57d1b94b
# ...                                        ...
# 2289  1df9b26b51ff3a153b93d79e25bef454e08a8e38
# 2290  197bb467c0fa33700e5397c934fa10d8c16f1fbc
# 2291  e71926c013ce254bbd7208a288677d0c2b336343
# 2292  c75cd9a8b9da86b9d9e7ffd6512fe13b1913fd85
# 2293  67adc54f349908a6a6d9f329406767253ddbce6e
#
# [2294 rows x 1 columns]

# %%
from pydriller import GitRepository

git_repo = GitRepository('../nova')
git_repo.get_commit('d0225509bdb7882324726312f4a4a9f63375203e').files
# Out:
# 2

# %%
len(df)
# Out:
# 8250

# %%
for i, row in df.iterrows():
    print(i)
    print(row)
    if i > 10:
        break
# Out:
# 0
# Project                                            cinder
# HashId           015555acb75ee4d9298915951d2bfaf0d19d2b02
# BugId                                             1301854
# BugType                                               Bug
# BugReportDate                                  1394502624
# FixDate                                        1396535798
# FixHashId        1fdb38fd4b43c2685658c1a7aa6a56c92ac31585
# File                     cinder/tests/test_vmware_vmdk.py
# Name: 0, dtype: object
# 1
# Project                                            cinder
# HashId           015555acb75ee4d9298915951d2bfaf0d19d2b02
# BugId                                             1332482
# BugType                                               Bug
# BugReportDate                                  1394502624
# FixDate                                        1403273920
# FixHashId        b07c1a759c8a0cdaaaaaf3e6f1ad7402bf631a44
# File                     cinder/tests/test_vmware_vmdk.py
# Name: 1, dtype: object
# 2
# Project                                            cinder
# HashId           0278a38153f9649aab1cc641bfabd8d5738d2d8c
# BugId                                             1246228
# BugType                                               Bug
# BugReportDate                                  1378717264
# FixDate                                        1383138656
# FixHashId        a29a1d8802d2fde8d09bed08e0595b4c0f85cf7b
# File                   cinder/api/contrib/types_manage.py
# Name: 2, dtype: object
# 3
# Project                                            cinder
# HashId           027b78a214e1f7ab7bbda342a024cb13dae8944d
# BugId                                             1250249
# BugType                                               Bug
# BugReportDate                                  1357682995
# FixDate                                        1384230241
# FixHashId        9834639454103ee2ba980628f0bc67ad0baa94ff
# File                          cinder/tests/test_hp3par.py
# Name: 3, dtype: object
# 4
# Project                                                  cinder
# HashId                 027b78a214e1f7ab7bbda342a024cb13dae8944d
# BugId                                                   1250249
# BugType                                                     Bug
# BugReportDate                                        1357682995
# FixDate                                              1384230241
# FixHashId              9834639454103ee2ba980628f0bc67ad0baa94ff
# File             cinder/volume/drivers/san/hp/hp_3par_common.py
# Name: 4, dtype: object
# 5
# Project                                                  cinder
# HashId                 027b78a214e1f7ab7bbda342a024cb13dae8944d
# BugId                                                   1269515
# BugType                                                     Bug
# BugReportDate                                        1357682995
# FixDate                                              1389825320
# FixHashId              99379d6ec00b7bdfe5a625877d8e680f9240efcc
# File             cinder/volume/drivers/san/hp/hp_3par_common.py
# Name: 5, dtype: object
# 6
# Project                                                  cinder
# HashId                 027b78a214e1f7ab7bbda342a024cb13dae8944d
# BugId                                                   1279478
# BugType                                                     Bug
# BugReportDate                                        1357682995
# FixDate                                              1392250568
# FixHashId              9090f99986c5b2cf725814e6ab64fd2d2a829d3e
# File             cinder/volume/drivers/san/hp/hp_3par_common.py
# Name: 6, dtype: object
# 7
# Project                                                  cinder
# HashId                 027b78a214e1f7ab7bbda342a024cb13dae8944d
# BugId                                                   1283233
# BugType                                                     Bug
# BugReportDate                                        1357682995
# FixDate                                              1393034207
# FixHashId              e31b9e78374bcaeae573cce2915897ceb870ffc3
# File             cinder/volume/drivers/san/hp/hp_3par_common.py
# Name: 7, dtype: object
# 8
# Project                                            cinder
# HashId           027b78a214e1f7ab7bbda342a024cb13dae8944d
# BugId                                             1315195
# BugType                                               Bug
# BugReportDate                                  1357682995
# FixDate                                        1399001411
# FixHashId        541cc9d53ac999535edcb7a02d1a76a883cfb02b
# File                          cinder/tests/test_hp3par.py
# Name: 8, dtype: object
# 9
# Project                                            cinder
# HashId           029435c9288d82dee5dd1113c3553ddb5b97c740
# BugId                                             1235358
# BugType                                               Bug
# BugReportDate                                  1360782809
# FixDate                                        1382017937
# FixHashId        6e287c0f2bb7d4994d50f1763f412277e4dac6f7
# File                             cinder/tests/test_rbd.py
# Name: 9, dtype: object
# 10
# Project                                            cinder
# HashId           029435c9288d82dee5dd1113c3553ddb5b97c740
# BugId                                             1235358
# BugType                                               Bug
# BugReportDate                                  1360782809
# FixDate                                        1382017937
# FixHashId        6e287c0f2bb7d4994d50f1763f412277e4dac6f7
# File                         cinder/volume/drivers/rbd.py
# Name: 10, dtype: object
# 11
# Project                                            cinder
# HashId           033d21f6f0a93ab664d7615e2c71486c7fbce03a
# BugId                                             1312718
# BugType                                               Bug
# BugReportDate                                  1360228263
# FixDate                                        1398445178
# FixHashId        38ed0523125efeaf8383b36d1db169b42e2f5eb6
# File                         cinder/volume/drivers/lvm.py
# Name: 11, dtype: object
